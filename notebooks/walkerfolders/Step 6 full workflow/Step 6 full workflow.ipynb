# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

from walker import Walker, plot_trajectory

# %% [markdown]
# For this Exercise let's go back to a version of the walker where we implemented the serialization.

# %% [markdown]
# # 1. Write a run.py script
# look back at the serialization notebook for reference, and copy the snippets if you dont remember:
# - Use the 'from_json' method to load some parameters
# - simulate some steps
# - (serializing the walker is not super necessary here, since the information should be the same as in the input file)

# %% [markdown]
# # 2. Save the data
# - save the simulated data
# - save relevant meta information about the run

# %% [markdown]
# # 3. Load the data in a notebook to visualize

# %%
trajectory = np.load("sim_20220820-164043.npy")

# %%
plt.plot(trajectory[:,0], trajectory[:,1])
