# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

from plotting import plot_trajectory
from walker import Walker

# %% [markdown]
# For this Exercise let's go back to the version of the walker with only one "next step proposal".

# %% [markdown]
# # 1. Complete the run.py script
# 1.  Open the `run.py` script; at the top we give the desired parameters for the run
# 2.  Save the parameters so that you can reproduce the same data
# 3.  Save the trajectory using `np.save()`
# 4.  Save some metadata about the run

# %% [markdown]
# # 2. Run the run.py script twice and compare that the outcome is identical by plotting the result below
#
# are they identical? If not, **why not**?

# %%
trajectory1 = np.load("sim1.npy") # change the name of the file here!
trajectory2 = np.load("sim2.npy") # change the name of the file here!

# %%
fig, ax = plt.subplots(1, 2, figsize=(8,4))
ax[0].plot(trajectory1[:,0], trajectory1[:,1])
ax[1].plot(trajectory2[:,0], trajectory2[:,1])
ax[0].set_title("Trajectory 1")
ax[1].set_title("Trajectory 2")
# Out:
# Text(0.5, 1.0, 'Trajectory 2')
